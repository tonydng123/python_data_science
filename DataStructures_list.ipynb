# %%
# Lists
print("Lists")
node_1 = "custom object"

my_data_type = [1, 2, False, 4, "Tony", None, node_1, 5.0, 1]
print(my_data_type)
print(type(my_data_type))
print(my_data_type[4])

# Dictionary
print("Dictionary")
my_data_type = {1: "hello", 2: "Tony", 3: None, 4: node_1, 5: 5.0}
print(my_data_type)
print(type(my_data_type))
print(my_data_type[2])

# Set
print("Set")
my_data_type = {1, 2, False, 4, "Tony", None, node_1, 5.0, 1, 1}
print(my_data_type)
print(type(my_data_type))

# Tuples
print("Tuples")
my_data_type = (1, 2, False, 4, "Tony", None, node_1, 5.0, 1, 1)
print(my_data_type)
print(type(my_data_type))

# List
my_list = [5, 6, 7, 8, 35, 12, 14, 4, 10]
print(f"Memory location of my_list: {id(my_list)}") # same memory location
my_str_list =["Comp sci", "physics", "elec engr", "philosophy"]
print(f"Ints: {my_list}")
print(f"Strings: {my_str_list}")
print("Sorting...")
sorted_list = sorted(my_list)
print(sorted_list)
my_list.sort()
print(f"sort my list: {my_list}")
print(f"Memory location of sorted_list: {id(sorted_list)}")
print(f"Memory location of my_list: {id(my_list)}") # same memory location

print("Finding info...")
print("physics" in my_str_list)
print("None" in my_str_list)
print(35 in my_list)
print(34 in my_list)
print(my_str_list.index("physics"))
print(min(my_list))
print(min(my_str_list))
print(max(my_list))
print(max(my_str_list))

# append(), insert(), extend()
my_list.append(24)
my_list.insert(4, 25)
print(my_list)
my_new_list = ["art", "econ"]
my_str_list.extend(my_new_list)
print(my_str_list)

# pop(), remove()
my_str_list.remove("Comp sci")
print(my_str_list)
my_str_list.pop()
print(my_str_list)

print("Sublists...")
print(my_list[:5])
print(my_list[5:])
print(my_list[::2])
my_list.reverse()
print(my_list)

for item in my_list:
    print(item)

print("HOME WORK 1")
# Question 1: Given the list below, print the min value from the list using the
# min function
my_list = [903,373,223,4031,2033,535,677,601,403,340,370,352,441,293,567,8888,1031,788,161]
## Write your code below, 1 line
print(min(my_list))
# End question 1

# Question 2: Given the list below, using the 'in' operator, print (True or False) if
# 'urgent' exists in the list.
my_words_list = ['extreme', 'arrow', 'urgently', 'important', 'Urgent', 'imperative']
## Write your code below, 1 line
print("urgent" in my_words_list)
# End question 2

# Question 3: Use the sorted function to sort my_list from question 1 and assign it to a variable
# named my_sorted_list
## Write your code below, 1 line
my_sorted_list = sorted(my_list)
# End question 3

# Question 4: Use the sort method to sort my_list from above and print out my_list below it
## Write your code below, 2 lines
my_list.sort()
print(f"my sort list: {my_list}")

# End question 4

# Question 5: Use the equality test to check if my_sorted_list is equal to my_list. Remember
# to print the result.
## Write your code below, 1 line
print(my_list == my_sorted_list)
# End question 5

print("HOME WORK 2")
# Question 1: Given the two lists below, add all the elements in the second list
# to the end of the first list, then print out the first list. Choose the
# appropriate method to add these elements so that you don't end up with a list
# within a list (as in the first list 'my_courses' should only have string data, 
# not lists of strings).
my_courses = ['comp sci','economics','physics','astronomy']
new_courses = ['climate studies','artificial intelligence']
## Write your code below, 2 lines ##
my_courses.extend(new_courses)
print(my_courses)
## End question 1

# Question 2: Given the string below, add it to the end of my_courses list which
# you printed at the end of question 1, then print out my_courses
new_course = 'tennis'
## Write your code below, 2 lines
my_courses.append(new_course)
print(my_courses)
# End question 2

# Question 3: Choose the approprite method to delete 'economics' from my_courses
# list and print the resulting my_courses list.
## Write your code below, 2 lines
my_courses.remove('economics')
print(my_courses)
# End question 3

# Question 4: Given the integer list below, print the length of the list (number
# of integers in the list).
my_int_list = [9,6,13,7,27,99,104,100,10,16,42,64]
## Write your code below, 1 line
print(len(my_int_list))
# End question 4

# Question 5: Grab the second half of my_int_list using slice notation and print
# it to the screen
## Write your code below, 1 line
print(my_int_list[len(my_int_list) // 2:])
# End question 5
# Out:
# Lists
# [1, 2, False, 4, 'Tony', None, 'custom object', 5.0, 1]
# <class 'list'>
# Tony
# Dictionary
# {1: 'hello', 2: 'Tony', 3: None, 4: 'custom object', 5: 5.0}
# <class 'dict'>
# Tony
# Set
# {False, 1, 2, 4, 5.0, 'custom object', 'Tony', None}
# <class 'set'>
# Tuples
# (1, 2, False, 4, 'Tony', None, 'custom object', 5.0, 1, 1)
# <class 'tuple'>
# Memory location of my_list: 140485834768832
# Ints: [5, 6, 7, 8, 35, 12, 14, 4, 10]
# Strings: ['Comp sci', 'physics', 'elec engr', 'philosophy']
# Sorting...
# [4, 5, 6, 7, 8, 10, 12, 14, 35]
# sort my list: [4, 5, 6, 7, 8, 10, 12, 14, 35]
# Memory location of sorted_list: 140485833862848
# Memory location of my_list: 140485834768832
# Finding info...
# True
# False
# True
# False
# 1
# 4
# Comp sci
# 35
# physics
# [4, 5, 6, 7, 25, 8, 10, 12, 14, 35, 24]
# ['Comp sci', 'physics', 'elec engr', 'philosophy', 'art', 'econ']
# ['physics', 'elec engr', 'philosophy', 'art', 'econ']
# ['physics', 'elec engr', 'philosophy', 'art']
# Sublists...
# [4, 5, 6, 7, 25]
# [8, 10, 12, 14, 35, 24]
# [4, 6, 25, 10, 14, 24]
# [24, 35, 14, 12, 10, 8, 25, 7, 6, 5, 4]
# 24
# 35
# 14
# 12
# 10
# 8
# 25
# 7
# 6
# 5
# 4
# HOME WORK 1
# 161
# False
# my sort list: [161, 223, 293, 340, 352, 370, 373, 403, 441, 535, 567, 601, 677, 788, 903, 1031, 2033, 4031, 8888]
# True
# HOME WORK 2
# ['comp sci', 'economics', 'physics', 'astronomy', 'climate studies', 'artificial intelligence']
# ['comp sci', 'economics', 'physics', 'astronomy', 'climate studies', 'artificial intelligence', 'tennis']
# ['comp sci', 'physics', 'astronomy', 'climate studies', 'artificial intelligence', 'tennis']
# 12
# [104, 100, 10, 16, 42, 64]
